# %%
from Bio import SeqIO

def parse_dictionary(dict_file):
    """
    Parse the dictionary file to create a mapping of VSG IDs to their classes.
    Returns a dictionary: {vsg_id: class_info}
    """
    vsg_dict = {}
    
    with open(dict_file, 'r') as f:
        for line in f:
            line = line.strip()
            if line.startswith('>'):
                # Remove the '>' character
                line = line[1:]
                # Split by space to separate ID and class
                parts = line.split()
                if len(parts) >= 2:
                    vsg_id = parts[0]  # e.g., "Tb427VSG-2"
                    class_info = parts[1]  # e.g., "BES" or "array_Chr9_5A_Tb427v10"
                    vsg_dict[vsg_id] = class_info
    
    return vsg_dict

def add_class_to_fasta(input_fasta, dict_file, output_fasta):
    """
    Read FASTA file and add class information to sequence IDs.
    Creates a new FASTA file with format: >{original_id}_{class}
    """
    # Parse the dictionary file
    vsg_dict = parse_dictionary(dict_file)
    
    # Process the FASTA file
    modified_records = []
    not_found = []
    
    for record in SeqIO.parse(input_fasta, "fasta"):
        original_id = record.id
        
        # Check if this ID exists in the dictionary
        if original_id in vsg_dict:
            # Add class information to the ID
            class_info = vsg_dict[original_id]
            record.id = f"{original_id}_{class_info}"
            record.description = f"{original_id}_{class_info}"
            modified_records.append(record)
        else:
            # Keep original if not found in dictionary
            not_found.append(original_id)
            modified_records.append(record)
    
    # Write the modified records to a new FASTA file
    SeqIO.write(modified_records, output_fasta, "fasta")
    
    print(f"Processed {len(modified_records)} sequences")
    print(f"Modified {len(modified_records) - len(not_found)} sequences with class information")
    
    if not_found:
        print(f"\nWarning: {len(not_found)} sequences not found in dictionary:")
        for id in not_found[:10]:  # Show first 10
            print(f"  - {id}")
        if len(not_found) > 10:
            print(f"  ... and {len(not_found) - 10} more")

# Example usage
if __name__ == "__main__":
    input_fasta = "VSGs_Sequences.fa"  # Replace with your FASTA file name
    dict_file = "vsg_dic.txt"
    output_fasta = "VSGs_Sequences_with_class.fasta"
    
    add_class_to_fasta(input_fasta, dict_file, output_fasta)
# Out:
# Processed 298 sequences
# Modified 298 sequences with class information

# %%
count_dict = {}
for n in open('VSGs_Sequences_with_class.fasta'):
    if n.startswith('>'):
        vsg_class = n.split('_')[1].strip()
        if vsg_class in count_dict:
            count_dict[vsg_class]+=1
        else:
            count_dict[vsg_class]=1
count_dict
# Out:
# {'BES': 14, 'MES': 5, 'MC': 62, 'array': 217}

# %%
#!mmseqs easy-cluster VSGs_Sequences.fa vsgsClusters/res_09_1 tmp --min-seq-id 0.9 -c 1 --cov-mode 1
# Out:
# Create directory tmp
# easy-cluster VSGs_Sequences.fa vsgsClusters/res_09_1 tmp --min-seq-id 0.9 -c 1 --cov-mode 1
#
# MMseqs Version:                     	18-8cc5c
# Substitution matrix                 	aa:blosum62.out,nucl:nucleotide.out
# Seed substitution matrix            	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                         	4
# k-mer length                        	0
# Target search mode                  	0
# k-score                             	seq:2147483647,prof:2147483647
# Alphabet size                       	aa:21,nucl:5
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	1
# Coverage mode                       	1
# Compositional bias                  	1
# Compositional bias scale            	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask residues probability           	0.9
# Mask lower case residues            	0
# Mask lower letter repeating N times 	0
# Minimum diagonal score              	15
# Selected taxa
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	substitution:1.100,context:1.400
# Pseudo count b                      	substitution:4.100,context:5.800
# Spaced k-mer pattern
# Local temporary path
# Threads                             	32
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.9
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Correlation score weight            	0
# Gap open cost                       	aa:11,nucl:5
# Gap extension cost                  	aa:1,nucl:2
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Weight file name
# Cluster Weight threshold            	0.9
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	true
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	aa:0.000,nucl:0.200
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
# Database type                       	0
# Shuffle input database              	true
# Createdb mode                       	1
# Write lookup file                   	0
# Offset of numeric ids               	0
# Use GPU                             	0
#
# createdb VSGs_Sequences.fa tmp/3863672305354947081/input --createdb-mode 1 --write-lookup 0
#
# Shuffle database cannot be combined with --createdb-mode 1
# We recompute with --shuffle 0
# Converting sequences
# Last byte is not a newline. We recompute with --createdb-mode 1
# Time for merging to input_h: 0h 0m 0s 2ms
# Time for merging to input: 0h 0m 0s 1ms
# [203] 0s 17ms
# Time for merging to input_h: 0h 0m 0s 10ms
# Time for merging to input: 0h 0m 0s 13ms
# Database type: Nucleotide
# Time for processing: 0h 0m 0s 47ms
# Create directory tmp/3863672305354947081/clu_tmp
# cluster tmp/3863672305354947081/input tmp/3863672305354947081/clu tmp/3863672305354947081/clu_tmp --max-seqs 20 -c 1 --cov-mode 1 --spaced-kmer-mode 1 --alignment-mode 3 -e 0.001 --min-seq-id 0.9 --remove-tmp-files 1
#
# Set cluster sensitivity to -s 1.000000
# Set cluster mode GREEDY MEM
# Set cluster iterations to 1
# linclust tmp/3863672305354947081/input tmp/3863672305354947081/clu_tmp/11199830744602886417/clu_redundancy tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 32 --compressed 0 -v 3 --cluster-weight-threshold 0.9 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 1 --cov-mode 1 --max-seq-len 10000 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --alph-size aa:21,nucl:5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 1 --force-reuse 0
#
# kmermatcher tmp/3863672305354947081/input tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:21,nucl:5 --min-seq-id 0.9 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --cov-mode 1 -k 0 -c 1 --max-seq-len 10000 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 32 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# kmermatcher tmp/3863672305354947081/input tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:21,nucl:5 --min-seq-id 0.9 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --cov-mode 1 -k 0 -c 1 --max-seq-len 10000 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 32 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Database size: 298 type: Nucleotide
#
# Generate k-mers list for 1 split
# [=================================================================] 100.00% 298 0s 26ms
#
# Adjusted k-mer length 17
# Sort kmer 0h 0m 0s 6ms
# Sort by rep. sequence 0h 0m 0s 0ms
# Time for fill: 0h 0m 0s 0ms
# Time for merging to pref: 0h 0m 0s 8ms
# Time for processing: 0h 0m 0s 69ms
# rescorediagonal tmp/3863672305354947081/input tmp/3863672305354947081/input tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pref tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pref_rescore1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 1 -a 0 --cov-mode 1 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 32 --compressed 0 -v 3
#
# [=================================================================] 100.00% 298 0s 5ms
# Time for merging to pref_rescore1: 0h 0m 0s 236ms
# Time for processing: 0h 0m 0s 284ms
# clust tmp/3863672305354947081/input tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pref_rescore1 tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pre_clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 32 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 5ms
#
# Size of the sequence database: 298
# Size of the alignment database: 298
# Number of clusters: 294
#
# Writing results 0h 0m 0s 0ms
# Time for merging to pre_clust: 0h 0m 0s 15ms
# Time for processing: 0h 0m 0s 122ms
# createsubdb tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/order_redundancy tmp/3863672305354947081/input tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 7ms
# Time for processing: 0h 0m 0s 16ms
# createsubdb tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/order_redundancy tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pref tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 4ms
# Time for processing: 0h 0m 0s 8ms
# filterdb tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pref_filter1 tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pref_filter2 --filter-file tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/order_redundancy --threads 32 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 100.00% 294 0s 4ms
# Time for merging to pref_filter2: 0h 0m 0s 514ms
# Time for processing: 0h 0m 0s 548ms
# align tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/input_step_redundancy tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/input_step_redundancy tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pref_filter2 tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 1 --cov-mode 1 --max-seq-len 10000 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 32 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 294 type: Nucleotide
# Target database size: 294 type: Nucleotide
# Calculation of alignments
# [=================================================================] 100.00% 294 0s 5ms
# Time for merging to aln: 0h 0m 0s 164ms
# 340 alignments calculated
# 294 sequence pairs passed the thresholds (0.864706 of overall calculated)
# 1.000000 hits per query sequence
# Time for processing: 0h 0m 0s 234ms
# clust tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/input_step_redundancy tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/aln tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 32 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 4ms
#
# Size of the sequence database: 294
# Size of the alignment database: 294
# Number of clusters: 294
#
# Writing results 0h 0m 0s 0ms
# Time for merging to clust: 0h 0m 0s 6ms
# Time for processing: 0h 0m 0s 20ms
# mergeclusters tmp/3863672305354947081/input tmp/3863672305354947081/clu_tmp/11199830744602886417/clu_redundancy tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pre_clust tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/clust --threads 32 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 100.00% 294 0s 2ms
# Clustering step 2
# [=================================================================] 100.00% 294 0s 6ms
# Write merged clustering
# [=================================================================] 100.00% 298 0s 28ms
# Time for merging to clu_redundancy: 0h 0m 0s 24ms
# Time for processing: 0h 0m 0s 57ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pref_filter1 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pref -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pref_rescore1 -v 3
#
# Time for processing: 0h 0m 0s 6ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pre_clust -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/input_step_redundancy -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/input_step_redundancy_h -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/pref_filter2 -v 3
#
# Time for processing: 0h 0m 0s 5ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/aln -v 3
#
# Time for processing: 0h 0m 0s 5ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/linclust/8532055206809851648/clust -v 3
#
# Time for processing: 0h 0m 0s 1ms
# createsubdb tmp/3863672305354947081/clu_tmp/11199830744602886417/clu_redundancy tmp/3863672305354947081/input tmp/3863672305354947081/clu_tmp/11199830744602886417/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 1ms
# Time for processing: 0h 0m 0s 5ms
# extractframes tmp/3863672305354947081/clu_tmp/11199830744602886417/input_step_redundancy tmp/3863672305354947081/clu_tmp/11199830744602886417/query_seqs --forward-frames 1 --reverse-frames 1 --translation-table 1 --translate 0 --create-lookup 0 --threads 32 --compressed 0 -v 3
#
# [=================================================================] 100.00% 294 0s 8ms
# Time for merging to query_seqs_h: 0h 0m 0s 423ms
# Time for merging to query_seqs: 0h 0m 0s 202ms
# Time for processing: 0h 0m 0s 706ms
# prefilter tmp/3863672305354947081/clu_tmp/11199830744602886417/query_seqs tmp/3863672305354947081/clu_tmp/11199830744602886417/input_step_redundancy tmp/3863672305354947081/clu_tmp/11199830744602886417/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 15 --target-search-mode 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 10000 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 1 --cov-mode 1 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 1 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --min-ungapped-score 60 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 32 --compressed 0 -v 3
#
# Query database size: 588 type: Nucleotide
# Estimated memory consumption: 8G
# Target database size: 294 type: Nucleotide
# Index table k-mer threshold: 0 at k-mer size 15
# Index table: counting k-mers
# [=================================================================] 100.00% 294 0s 26ms
# Index table: Masked residues: 696
# Index table: fill
# [=================================================================] 100.00% 294 0s 18ms
# Index statistics
# Entries:          343911
# DB size:          8193 MB
# Avg k-mer size:   0.000320
# Top 10 k-mers
#     GAAATCAAACAAAAA	3
#     GTTATCAATAGAAAA	3
#     CATGACTTCTGAAAA	3
#     AAGACAGCAAACAAA	3
#     TTGATTTCGGACAAA	3
#     AAACCACTAACCAAA	3
#     GAATACTTCGAGAAA	3
#     ATTCCTTTTGAACAA	3
#     TTGAACATAAATCAA	3
#     TCCGAGGAAGATCAA	3
# Time for index table init: 0h 0m 1s 854ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 0
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 588
# Target db start 1 to 294
# [=================================================================] 100.00% 588 0s 16ms
# [================================================================>] 99.83% 587 eta 0s
# 0.981197 k-mers per position
# 606 DB matches per sequence
# 0 overflows
# 0 sequences passed prefiltering per query sequence
# 1 median result list length
# 294 sequences with 0 size result lists
# Time for merging to pref: 0h 0m 0s 414ms
# Time for processing: 0h 0m 2s 464ms
# rescorediagonal tmp/3863672305354947081/clu_tmp/11199830744602886417/query_seqs tmp/3863672305354947081/clu_tmp/11199830744602886417/input_step_redundancy tmp/3863672305354947081/clu_tmp/11199830744602886417/pref tmp/3863672305354947081/clu_tmp/11199830744602886417/aln_ungapped --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 2 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 1 -a 0 --cov-mode 1 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 32 --compressed 0 -v 3
#
# [=================================================================] 100.00% 588 0s 5ms
# Time for merging to aln_ungapped: 0h 0m 0s 218ms===========>      ] 90.12% 530 eta 0s
# Time for processing: 0h 0m 0s 255ms
# subtractdbs tmp/3863672305354947081/clu_tmp/11199830744602886417/pref tmp/3863672305354947081/clu_tmp/11199830744602886417/aln_ungapped tmp/3863672305354947081/clu_tmp/11199830744602886417/pref_subtract --threads 32 --compressed 0 -v 3
#
# [=================================================================] 100.00% 588 0s 9ms
# Time for merging to pref_subtract: 0h 0m 0s 211ms
# Time for processing: 0h 0m 0s 252ms
# align tmp/3863672305354947081/clu_tmp/11199830744602886417/query_seqs tmp/3863672305354947081/clu_tmp/11199830744602886417/input_step_redundancy tmp/3863672305354947081/clu_tmp/11199830744602886417/pref_subtract tmp/3863672305354947081/clu_tmp/11199830744602886417/aln_gapped --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 1 --cov-mode 1 --max-seq-len 10000 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 32 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 588 type: Nucleotide
# Target database size: 294 type: Nucleotide
# Calculation of alignments
# [=================================================================] 100.00% 588 0s 5ms
# Time for merging to aln_gapped: 0h 0m 0s 390ms
# 36 alignments calculated
# 0 sequence pairs passed the thresholds (0.000000 of overall calculated)
# 0.000000 hits per query sequence
# Time for processing: 0h 0m 0s 449ms
# concatdbs tmp/3863672305354947081/clu_tmp/11199830744602886417/aln_ungapped tmp/3863672305354947081/clu_tmp/11199830744602886417/aln_gapped tmp/3863672305354947081/clu_tmp/11199830744602886417/aln --preserve-keys --take-larger-entry --threads 32 --compressed 0 -v 3
#
# [=================================================================] 100.00% 588 0s 13ms
# [=================================================================] 100.00% 588 0s 20ms
# Time for merging to aln: 0h 0m 0s 235ms
# Time for processing: 0h 0m 0s 429ms
# offsetalignment tmp/3863672305354947081/clu_tmp/11199830744602886417/input_step_redundancy tmp/3863672305354947081/clu_tmp/11199830744602886417/query_seqs tmp/3863672305354947081/clu_tmp/11199830744602886417/input_step_redundancy tmp/3863672305354947081/clu_tmp/11199830744602886417/input_step_redundancy tmp/3863672305354947081/clu_tmp/11199830744602886417/aln tmp/3863672305354947081/clu_tmp/11199830744602886417/aln_off --chain-alignments 0 --merge-query 1 --search-type 3 --threads 32 --compressed 0 --db-load-mode 0 -v 3
#
# Computing ORF lookup
# Computing contig offsets
# Computing contig lookup
# Time for contig lookup: 0h 0m 0s 2ms
# Writing results to: tmp/3863672305354947081/clu_tmp/11199830744602886417/aln_off
# [=================================================================] 100.00% 298 0s 3ms
#
# Time for merging to aln_off: 0h 0m 0s 297ms
# Time for processing: 0h 0m 0s 350ms
# clust tmp/3863672305354947081/clu_tmp/11199830744602886417/input_step_redundancy tmp/3863672305354947081/clu_tmp/11199830744602886417/aln_off tmp/3863672305354947081/clu_tmp/11199830744602886417/clu --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 32 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 3ms
#
# Size of the sequence database: 294
# Size of the alignment database: 294
# Number of clusters: 294
#
# Writing results 0h 0m 0s 0ms
# Time for merging to clu: 0h 0m 0s 2ms
# Time for processing: 0h 0m 0s 13ms
# mergeclusters tmp/3863672305354947081/input tmp/3863672305354947081/clu tmp/3863672305354947081/clu_tmp/11199830744602886417/clu_redundancy tmp/3863672305354947081/clu_tmp/11199830744602886417/clu --threads 32 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 100.00% 294 0s 3ms
# Clustering step 2
# [=================================================================] 100.00% 294 0s 7ms
# Write merged clustering
# [=================================================================] 100.00% 298 0s 22ms
# Time for merging to clu: 0h 0m 0s 19ms
# Time for processing: 0h 0m 0s 46ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/query_seqs -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/clu_redundancy -v 3
#
# Time for processing: 0h 0m 0s 5ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/input_step_redundancy -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/perf -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/aln -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/aln_off -v 3
#
# Time for processing: 0h 0m 0s 5ms
# rmdb tmp/3863672305354947081/clu_tmp/11199830744602886417/clu -v 3
#
# Time for processing: 0h 0m 0s 1ms
# createtsv tmp/3863672305354947081/input tmp/3863672305354947081/input tmp/3863672305354947081/clu tmp/3863672305354947081/cluster.tsv --threads 32 -v 3
#
# Time for merging to cluster.tsv: 0h 0m 0s 33ms
# Time for processing: 0h 0m 0s 49ms
# result2repseq tmp/3863672305354947081/input tmp/3863672305354947081/clu tmp/3863672305354947081/clu_rep --db-load-mode 0 --compressed 0 --threads 32 -v 3
#
# [=================================================================] 100.00% 294 0s 1ms
# Time for merging to clu_rep: 0h 0m 0s 24ms
# Time for processing: 0h 0m 0s 39ms
# result2flat tmp/3863672305354947081/input tmp/3863672305354947081/input tmp/3863672305354947081/clu_rep tmp/3863672305354947081/rep_seq.fasta --use-fasta-header -v 3
#
# Time for processing: 0h 0m 0s 2ms
# createseqfiledb tmp/3863672305354947081/input tmp/3863672305354947081/clu tmp/3863672305354947081/clu_seqs --threads 32 -v 3
#
# [=================================================================] 100.00% 294 0s 2ms
# Time for merging to clu_seqs: 0h 0m 0s 219ms
# Time for processing: 0h 0m 0s 235ms
# result2flat tmp/3863672305354947081/input tmp/3863672305354947081/input tmp/3863672305354947081/clu_seqs tmp/3863672305354947081/all_seqs.fasta -v 3
#
# Time for processing: 0h 0m 0s 8ms
# rmdb tmp/3863672305354947081/input -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/3863672305354947081/input_h -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/3863672305354947081/clu_seqs -v 3
#
# Time for processing: 0h 0m 0s 5ms
# rmdb tmp/3863672305354947081/clu_rep -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/3863672305354947081/clu -v 3
#
# Time for processing: 0h 0m 0s 5ms

# %%
# !mkdir -p vsgsSearch
# !mmseqs easy-search --search-type 3 --format-mode 4 VSGs_Sequences_with_class.fasta TriTrypDB-68_TbruceiLister427_2018_Genome.fasta vsgsSearch/res_vsg.m8 tmp
# Out:
# Create directory tmp
# easy-search --search-type 3 --format-mode 4 VSGs_Sequences_with_class.fasta TriTrypDB-68_TbruceiLister427_2018_Genome.fasta vsgsSearch/res_vsg.m8 tmp
#
# MMseqs Version:                        	18-8cc5c
# Substitution matrix                    	aa:blosum62.out,nucl:nucleotide.out
# Add backtrace                          	false
# Alignment mode                         	3
# Alignment mode                         	0
# Allow wrapped scoring                  	false
# E-value threshold                      	0.001
# Seq. id. threshold                     	0
# Min alignment length                   	0
# Seq. id. mode                          	0
# Alternative alignments                 	0
# Coverage threshold                     	0
# Coverage mode                          	0
# Max sequence length                    	65535
# Compositional bias                     	1
# Compositional bias scale               	1
# Max reject                             	2147483647
# Max accept                             	2147483647
# Include identical seq. id.             	false
# Preload mode                           	0
# Pseudo count a                         	substitution:1.100,context:1.400
# Pseudo count b                         	substitution:4.100,context:5.800
# Score bias                             	0
# Realign hits                           	false
# Realign score bias                     	-0.2
# Realign max seqs                       	2147483647
# Correlation score weight               	0
# Gap open cost                          	aa:11,nucl:5
# Gap extension cost                     	aa:1,nucl:2
# Zdrop                                  	40
# Threads                                	32
# Compressed                             	0
# Verbosity                              	3
# Seed substitution matrix               	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                            	5.7
# k-mer length                           	0
# Target search mode                     	0
# k-score                                	seq:2147483647,prof:2147483647
# Alphabet size                          	aa:21,nucl:5
# Max results per query                  	300
# Split database                         	0
# Split mode                             	2
# Split memory limit                     	0
# Diagonal scoring                       	true
# Exact k-mer matching                   	0
# Mask residues                          	1
# Mask residues probability              	0.9
# Mask lower case residues               	0
# Mask lower letter repeating N times    	0
# Minimum diagonal score                 	15
# Selected taxa
# Spaced k-mers                          	1
# Spaced k-mer pattern
# Local temporary path
# Use GPU                                	0
# Use GPU server                         	0
# Wait for GPU server                    	600
# Prefilter mode                         	0
# Rescore mode                           	0
# Remove hits by seq. id. and coverage   	false
# Sort results                           	0
# Mask profile                           	1
# Profile E-value threshold              	0.001
# Global sequence weighting              	false
# Allow deletions                        	false
# Filter MSA                             	1
# Use filter only at N seqs              	0
# Maximum seq. id. threshold             	0.9
# Minimum seq. id.                       	0.0
# Minimum score per column               	-20
# Minimum coverage                       	0
# Select N most diverse seqs             	1000
# Pseudo count mode                      	0
# Profile output mode                    	0
# Min codons in orf                      	30
# Max codons in length                   	32734
# Max orf gaps                           	2147483647
# Contig start mode                      	2
# Contig end mode                        	2
# Orf start mode                         	1
# Forward frames                         	1,2,3
# Reverse frames                         	1,2,3
# Translation table                      	1
# Translate orf                          	0
# Use all table starts                   	false
# Offset of numeric ids                  	0
# Create lookup                          	0
# Overlap between sequences              	0
# Sequence split mode                    	1
# Header split mode                      	0
# Chain overlapping alignments           	0
# Merge query                            	1
# Search type                            	3
# Search iterations                      	1
# Start sensitivity                      	4
# Search steps                           	1
# Exhaustive search mode                 	false
# Filter results during exhaustive search	0
# Strand selection                       	1
# LCA search mode                        	false
# Disk space limit                       	0
# MPI runner
# Force restart with latest tmp          	false
# Remove temporary files                 	true
# Translation mode                       	0
# Alignment format                       	4
# Format alignment output                	query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits
# Database output                        	false
# Overlap threshold                      	0
# Database type                          	0
# Shuffle input database                 	true
# Createdb mode                          	0
# Write lookup file                      	0
# Greedy best hits                       	false
#
# createdb VSGs_Sequences_with_class.fasta tmp/10509856216311723327/query
#
# Converting sequences
# [203] 0s 84ms
# Time for merging to query_h: 0h 0m 0s 426ms
# Time for merging to query: 0h 0m 0s 293ms
# Database type: Nucleotide
# Time for processing: 0h 0m 0s 857ms
# createdb TriTrypDB-68_TbruceiLister427_2018_Genome.fasta tmp/10509856216311723327/target --write-lookup 0 --gpu 0
#
# Converting sequences
# [304] 0s 88ms
# Time for merging to target_h: 0h 0m 0s 464ms
# Time for merging to target: 0h 0m 0s 303ms
# Database type: Nucleotide
# Time for processing: 0h 0m 0s 928ms
# Create directory tmp/10509856216311723327/search_tmp
# search tmp/10509856216311723327/query tmp/10509856216311723327/target tmp/10509856216311723327/result tmp/10509856216311723327/search_tmp --alignment-mode 3 -s 5.7 --search-type 3 --remove-tmp-files 1
#
# splitsequence tmp/10509856216311723327/target tmp/10509856216311723327/search_tmp/12104098505940412431/target_seqs_split --max-seq-len 10000 --sequence-overlap 0 --sequence-split-mode 1 --headers-split-mode 0 --create-lookup 0 --threads 32 --compressed 0 -v 3
#
# [=================================================================] 100.00% 317 0s 5ms
# Time for merging to target_seqs_split_h: 0h 0m 0s 284ms
# Time for merging to target_seqs_split: 0h 0m 0s 217ms
# Time for processing: 0h 0m 0s 600ms
# extractframes tmp/10509856216311723327/query tmp/10509856216311723327/search_tmp/12104098505940412431/query_seqs --forward-frames 1 --reverse-frames 1 --translation-table 1 --translate 0 --create-lookup 0 --threads 32 --compressed 0 -v 3
#
# [=================================================================] 100.00% 298 0s 11ms
# Time for merging to query_seqs_h: 0h 0m 0s 384ms
# Time for merging to query_seqs: 0h 0m 0s 211ms
# Time for processing: 0h 0m 0s 702ms
# splitsequence tmp/10509856216311723327/search_tmp/12104098505940412431/query_seqs tmp/10509856216311723327/search_tmp/12104098505940412431/query_seqs_split --max-seq-len 10000 --sequence-overlap 0 --sequence-split-mode 1 --headers-split-mode 0 --create-lookup 0 --threads 32 --compressed 0 -v 3
#
# Time for processing: 0h 0m 0s 5ms
# prefilter tmp/10509856216311723327/search_tmp/12104098505940412431/query_seqs_split tmp/10509856216311723327/search_tmp/12104098505940412431/target_seqs_split tmp/10509856216311723327/search_tmp/12104098505940412431/search/pref_0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -k 15 --target-search-mode 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 10000 --max-seqs 300 --split 0 --split-mode 2 --split-memory-limit 0 -c 0 --cov-mode 0 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 1 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 32 --compressed 0 -v 3 -s 5.7
#
# Query database size: 596 type: Nucleotide
# Estimated memory consumption: 8G
# Target database size: 5164 type: Nucleotide
# Index table k-mer threshold: 0 at k-mer size 15
# Index table: counting k-mers
# [=================================================================] 100.00% 5.16K 0s 316ms
# Index table: Masked residues: 1563396
# Index table: fill
# [=================================================================] 100.00% 5.16K 0s 479ms
# Index statistics
# Entries:          45212305
# DB size:          8450 MB
# Avg k-mer size:   0.042107
# Top 10 k-mers
#     TTAATATTGTTCAAC	534
#     ATTGATATCATACAC	471
#     TTATTAATTTAATCA	459
#     ATATGTATTAATCCA	425
#     TATTCACATCAACCT	417
#     ATAAACACCACCTTC	414
#     CTTTATAAATTTAAC	391
#     ATTTATATCGAACCA	387
#     GTGAATACAATTATA	386
#     TGTATGTGATCAAAT	380
# Time for index table init: 0h 0m 2s 779ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 0
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 596
# Target db start 1 to 5164
# [=================================================================] 100.00% 596 0s 29ms
#
# 0.981203 k-mers per position
# 1015 DB matches per sequence
# 0 overflows
# 5 sequences passed prefiltering per query sequence
# 3 median result list length
# 52 sequences with 0 size result lists
# Time for merging to pref_0: 0h 0m 0s 325ms
# Time for processing: 0h 0m 3s 377ms
# align tmp/10509856216311723327/search_tmp/12104098505940412431/query_seqs_split tmp/10509856216311723327/search_tmp/12104098505940412431/target_seqs_split tmp/10509856216311723327/search_tmp/12104098505940412431/search/pref_0 tmp/10509856216311723327/search_tmp/12104098505940412431/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0 --cov-mode 0 --max-seq-len 10000 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 32 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 596 type: Nucleotide
# Target database size: 5164 type: Nucleotide
# Calculation of alignments
# [=================================================================] 100.00% 596 0s 20ms
# Time for merging to aln: 0h 0m 0s 44ms
# 3012 alignments calculated
# 2678 sequence pairs passed the thresholds (0.889110 of overall calculated)
# 4.493289 hits per query sequence
# Time for processing: 0h 0m 0s 100ms
# rmdb tmp/10509856216311723327/search_tmp/12104098505940412431/search/pref_0 -v 3
#
# Time for processing: 0h 0m 0s 5ms
# rmdb tmp/10509856216311723327/search_tmp/12104098505940412431/search/aln_0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/10509856216311723327/search_tmp/12104098505940412431/search/input_0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/10509856216311723327/search_tmp/12104098505940412431/search/aln_merge -v 3
#
# Time for processing: 0h 0m 0s 0ms
# offsetalignment tmp/10509856216311723327/query tmp/10509856216311723327/search_tmp/12104098505940412431/query_seqs_split tmp/10509856216311723327/target tmp/10509856216311723327/search_tmp/12104098505940412431/target_seqs_split tmp/10509856216311723327/search_tmp/12104098505940412431/aln tmp/10509856216311723327/result --chain-alignments 0 --merge-query 1 --search-type 3 --threads 32 --compressed 0 --db-load-mode 0 -v 3
#
# Computing ORF lookup
# Computing contig offsets
# Computing contig lookup
# Time for contig lookup: 0h 0m 0s 0ms
# Writing results to: tmp/10509856216311723327/result
# [=================================================================] 100.00% 298 0s 3ms
#
# Time for merging to result: 0h 0m 0s 441ms
# Time for processing: 0h 0m 0s 471ms
# rmdb tmp/10509856216311723327/search_tmp/12104098505940412431/q_orfs -v 3
#
# Time for processing: 0h 0m 0s 3ms
# rmdb tmp/10509856216311723327/search_tmp/12104098505940412431/q_orfs_aa -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/10509856216311723327/search_tmp/12104098505940412431/t_orfs -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/10509856216311723327/search_tmp/12104098505940412431/t_orfs_aa -v 3
#
# Time for processing: 0h 0m 0s 0ms
# convertalis tmp/10509856216311723327/query tmp/10509856216311723327/target tmp/10509856216311723327/result vsgsSearch/res_vsg.m8 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --format-mode 4 --format-output query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits --translation-table 1 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --db-output 0 --db-load-mode 0 --search-type 3 --threads 32 --compressed 0 -v 3
#
# [=================================================================] 100.00% 298 0s 8ms
# Time for merging to res_vsg.m8: 0h 0m 0s 183ms
# Time for processing: 0h 0m 0s 232ms
# rmdb tmp/10509856216311723327/result -v 3
#
# Time for processing: 0h 0m 0s 8ms
# rmdb tmp/10509856216311723327/target -v 3
#
# Time for processing: 0h 0m 0s 3ms
# rmdb tmp/10509856216311723327/target_h -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/10509856216311723327/query -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/10509856216311723327/query_h -v 3
#
# Time for processing: 0h 0m 0s 1ms

# %%
# !rm -r tmp

# %%
import pandas as pd

# %%
#df = pd.read_csv('vsgsSearch/res_vsg.m8',sep='\t')
#for i,n in enumerate(df['query']):
#    print(i,n,n.split('_')[1])
df = pd.read_csv('vsgsSearch/res_vsg.m8',sep='\t')
df['VSG_CLASS']=[n.split('_')[1].split('_')[0]  for n in df['query']]
df['VSG_CLASS'].unique()
# Out:
# array(['MC', 'array', 'BES', 'MES'], dtype=object)

# %%
df = pd.read_csv('vsgsSearch/res_vsg.m8',sep='\t')
df.sort_values('evalue')
# Out:
#                                                   query  \
# 0                                       Tb427VSG-600_MC
# 1227  Tb427VSG-324_array_Chr2_5A_Tb427v10:Chr9_3A_Tb...
# 1228  Tb427VSG-324_array_Chr2_5A_Tb427v10:Chr9_3A_Tb...
# 1229  Tb427VSG-324_array_Chr2_5A_Tb427v10:Chr9_3A_Tb...
# 1230  Tb427VSG-324_array_Chr2_5A_Tb427v10:Chr9_3A_Tb...
# ...                                                 ...
# 2328                Tb427VSG-449_array_Chr9_5B_Tb427v10
# 2304                                    Tb427VSG-476_MC
# 2303                                    Tb427VSG-476_MC
# 140                                     Tb427VSG-672_MC
# 142                                     Tb427VSG-672_MC
#
#                             target  fident  alnlen  mismatch  gapopen  qstart  \
# 0     Tb427VSG-600_unitig_Tb427v10   1.000    1200         0        0       1
# 1227              Chr6_3A_Tb427v10   0.900    1200       120        0    1200
# 1228              Chr1_3A_Tb427v10   0.889    1200       133        0    1200
# 1229             Chr11_3A_Tb427v10   0.869    1200       157        0       1
# 1230              Chr4_3A_Tb427v10   0.807    1200       231        0    1200
# ...                            ...     ...     ...       ...      ...     ...
# 2328              Chr1_3A_Tb427v10   0.850      40         6        0     631
# 2304              Chr1_3A_Tb427v10   0.885      35         4        0    1134
# 2303              Chr7_5A_Tb427v10   0.885      35         4        0    1099
# 140               Chr5_3B_Tb427v10   0.770      61        13        0    1196
# 142               Chr9_3A_Tb427v10   0.891      37         4        0    1191
#
#       qend   tstart     tend    evalue  bits
# 0     1200     5115     6314  0.000000  2151
# 1227     1  1282067  1283263  0.000000  1610
# 1228     1   143859   145058  0.000000  1547
# 1229  1200   100042   101241  0.000000  1446
# 1230     1   576627   577826  0.000000  1112
# ...    ...      ...      ...       ...   ...
# 2328   592   457404   457443  0.000674    46
# 2304  1100   494371   494405  0.000674    46
# 2303  1133   554618   554652  0.000674    46
# 140   1139   212005   212065  0.000674    46
# 142   1155  1230149  1230184  0.000674    46
#
# [2678 rows x 12 columns]

# %%
df = pd.read_csv('vsgsSearch/res_vsg.m8',sep='\t')
df['VSG_CLASS']=[n.split('_')[1].split('_')[0]  for n in df['query']]
df = df[(df['VSG_CLASS']=='array') & (df['target'].str.contains('unitig'))]
print(len(df['query'].unique()))
df.sort_values('evalue').head()
open('exclude_array.txt','w').write('\n'.join( [n.split('_')[0] for n in list(df['query'].unique())] ))
# Out:
# 26
# 337

# %%
df = pd.read_csv('vsgsSearch/res_vsg.m8',sep='\t')
df['VSG_CLASS']=[n.split('_')[1].split('_')[0]  for n in df['query']]
df = df[(df['VSG_CLASS']=='MC') & (df['target'].str.startswith('Chr'))]
print(len(df['query'].unique()))
df.head()
open('exclude_MC.txt','w').write('\n'.join( [n.split('_')[0] for n in list(df['query'].unique())] ))
# Out:
# 59
# 774

# %%
df = pd.read_csv('vsgsSearch/res_vsg.m8',sep='\t')
df['VSG_CLASS']=[n.split('_')[1].split('_')[0]  for n in df['query']]
df['VSG_CLASS'].value_counts()
# Out:
# VSG_CLASS
# array    1306
# MC       1231
# BES       121
# MES        20
# Name: count, dtype: int64

# %%
df[~df['query'].duplicated(keep=False)]['VSG_CLASS'].value_counts()
# Out:
# VSG_CLASS
# array    38
# MC        5
# MES       1
# BES       1
# Name: count, dtype: int64

# %%
#!pwd

# %%
df = pd.read_csv('vsgsSearch/res_vsg.m8',sep='\t')
df['VSG_CLASS']=[n.split('_')[1].split('_')[0]  for n in df['query']]
df = df[(df['VSG_CLASS']=='array') ]
df.tail()
# Out:
#                                                   query             target  \
# 2673  Tb427VSG-352_array_Chr9_3A_Tb427v10:Chr8_5A_Tb...   Chr1_5A_Tb427v10
# 2674  Tb427VSG-352_array_Chr9_3A_Tb427v10:Chr8_5A_Tb...  Chr10_3A_Tb427v10
# 2675  Tb427VSG-352_array_Chr9_3A_Tb427v10:Chr8_5A_Tb...   Chr1_3B_Tb427v10
# 2676               Tb427VSG-367_array_Chr10_3B_Tb427v10  Chr10_3B_Tb427v10
# 2677               Tb427VSG-431_array_Chr10_3B_Tb427v10  Chr10_3B_Tb427v10
#
#       fident  alnlen  mismatch  gapopen  qstart  qend   tstart     tend  \
# 2673   0.913    1200       104        0       1  1200   112703   113902
# 2674   0.872    1200       153        0       1  1200  1203452  1204651
# 2675   0.872    1200       153        0    1200     1   554390   555589
# 2676   1.000    1200         0        0       1  1200   124558   125757
# 2677   1.000    1200         0        0    1200     1   800352   801551
#
#       evalue  bits VSG_CLASS
# 2673     0.0  1678     array
# 2674     0.0  1466     array
# 2675     0.0  1449     array
# 2676     0.0  2151     array
# 2677     0.0  2151     array

# %%
import json
with open('vsgs_web_server/data/exp_config.json', 'r') as f:
    exp_config = json.load(f)
all_treatments = []
for key in exp_config:
    all_treatments+=exp_config[key]['treatments']
len(all_treatments),all_treatments[0:3]
# Out:
# (216, ['SRR2154098', 'SRR2154094', 'SRR2154095'])

# %%
import os
def open_counts(temp_id):
    path = f'../myRna-seq/results/result_vsgs/{temp_id}'
    for fname in os.listdir(path):
        if fname.endswith('_all.txt'):
            tmp_df = pd.read_csv(f'{path}/{fname}',sep='\t',comment='#')
            cols =  list(tmp_df.columns)
            cols[-1]='counts'
            tmp_df.columns = cols
            tmp_df.set_index('Geneid',inplace=True)
            return tmp_df
all_treatments_counts = []

for temp_id in all_treatments:
    tmp_df = open_counts(temp_id)
    tmp_df = tmp_df[['counts']]
    tmp_df.columns=[temp_id]
    all_treatments_counts.append(tmp_df)
all_treatments_counts=pd.concat(all_treatments_counts,axis=1)
all_treatments_counts
# Out:
#                      SRR2154098  SRR2154094  SRR2154095  SRR2154096  \
# Geneid
# Tb927.1.05                    0          12           1           1
# Tb927.1.10                    0           0           0           0
# Tb927.1.30                   14          20           6           2
# Tb927.1.40                    6         610           4           4
# Tb927.1.70                  822        1839         965         888
# ...                         ...         ...         ...         ...
# lncRNA_curated_4102        1745        2928        1345        1169
# lncRNA_curated_4104        1367        2543        1329        1208
# lncRNA_curated_4105        1368        2543        1330        1208
# lncRNA_curated_4111         954        1947        1941        1545
# lncRNA_curated_4113        1240       21103        1243        1299
#
#                      SRR2154091  SRR2154088  SRR2154092  SRR2154089  \
# Geneid
# Tb927.1.05                    0           0           0           2
# Tb927.1.10                    0           0           0           0
# Tb927.1.30                    3          10           5           7
# Tb927.1.40                    2           6           9          20
# Tb927.1.70                 1003        1586        1699        1588
# ...                         ...         ...         ...         ...
# lncRNA_curated_4102        1356        2004        2476        1380
# lncRNA_curated_4104        1414        2091        2303        1472
# lncRNA_curated_4105        1415        2092        2304        1473
# lncRNA_curated_4111        2415        3576        3787        2613
# lncRNA_curated_4113        1575        1995        2392        1336
#
#                      ERR3447799  ERR3447800  ...  ERR3383644  ERR3383646  \
# Geneid                                       ...
# Tb927.1.05                    1           1  ...           5           7
# Tb927.1.10                    0           0  ...           0           0
# Tb927.1.30                   11           7  ...           2           7
# Tb927.1.40                   52          47  ...          13          19
# Tb927.1.70                  252         239  ...        2467        1342
# ...                         ...         ...  ...         ...         ...
# lncRNA_curated_4102         251         225  ...        1335         633
# lncRNA_curated_4104         185         188  ...        1561         618
# lncRNA_curated_4105         185         188  ...        1563         619
# lncRNA_curated_4111         231         257  ...        1385         904
# lncRNA_curated_4113         222         235  ...        1593         728
#
#                      ERR3380229  ERR3380233  ERR3380232  ERR3380236  \
# Geneid
# Tb927.1.05                    8           8           0           5
# Tb927.1.10                    0           0           0           0
# Tb927.1.30                    8           8           0           1
# Tb927.1.40                   42          20           0           4
# Tb927.1.70                 1242        1179          59         387
# ...                         ...         ...         ...         ...
# lncRNA_curated_4102        3320        2805         181         389
# lncRNA_curated_4104        4105        3369         214         665
# lncRNA_curated_4105        4106        3372         214         665
# lncRNA_curated_4111        2546        3718         339        1695
# lncRNA_curated_4113        4747        3139         310         981
#
#                      ERR3380231  ERR3380235  ERR3380230  ERR3380234
# Geneid
# Tb927.1.05                    1           1           0           0
# Tb927.1.10                    0           0           0           0
# Tb927.1.30                    1           0           0           1
# Tb927.1.40                    1           0           0           0
# Tb927.1.70                   92         192          40          80
# ...                         ...         ...         ...         ...
# lncRNA_curated_4102         145         133          48          29
# lncRNA_curated_4104         183         170          49          38
# lncRNA_curated_4105         183         170          49          38
# lncRNA_curated_4111         236         515          77          97
# lncRNA_curated_4113         364         414         111          79
#
# [11239 rows x 216 columns]

# %%
vsg_counts = all_treatments_counts[all_treatments_counts.index.str.contains('VSG')]
vsg_counts['has_value_gte_10'] = (vsg_counts >= 10).any(axis=1)
vsg_counts['has_value_gte_10'].value_counts()
# Out:
# /var/folders/c8/lvfcy73x5jl6yvb91241cvdh0000gp/T/ipykernel_94651/884445362.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vsg_counts['has_value_gte_10'] = (vsg_counts >= 10).any(axis=1)
# /var/folders/c8/lvfcy73x5jl6yvb91241cvdh0000gp/T/ipykernel_94651/884445362.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vsg_counts['has_value_gte_10'] = (vsg_counts >= 10).any(axis=1)
# has_value_gte_10
# True     291
# False      7
# Name: count, dtype: int64

# %%
open('exclude_count.txt','w').write('\n'.join( [n.split('_')[1] for n in list(vsg_counts[~vsg_counts['has_value_gte_10']].index.values)] ))
# Out:
# 90
